# %% [markdown]
# # Visualizing word embeddings : Deep Learning for NLP embeddings.
#
# This notebook will guide you through the implementation of Word2Vec, a popular model used in Natural Language Processing (NLP) to capture semantic meaning from text. We will apply this model to a dataset and visualize the learned word embeddings.

# %% [markdown]
# <center><img src="https://education-team-2020.s3.eu-west-1.amazonaws.com/ai-eng/w4-s3/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ## Tutorial
#
# In this notebook, we will apply the Word2Vec model to a text dataset. The Word2Vec model learns to represent words in a continuous vector space, where semantically similar words are mapped to nearby points. We will walk through the following steps:
#
# 1. **Download the Training Data:** We'll start by downloading a large text corpus for training.
# 2. **Set up Word2Vec in TensorFlow:** We'll configure the Word2Vec model using TensorFlow, a popular machine learning library.
# 3. **Train the Model:** We'll train the Word2Vec model on the dataset to learn word embeddings.
# 4. **Visualize the Embeddings:** Finally, we'll visualize the learned word embeddings using dimensionality reduction techniques.

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ### Step 1: Download the Dataset
#
# To train our Word2Vec model, we need a large text corpus. In this step, we will download the "text8" dataset, a popular dataset used for training word embeddings. This dataset contains 100 MB of English Wikipedia text from 2006, which is commonly used in NLP tasks.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""

    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)

    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')

    return filename

path = ""
filename = maybe_download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# > **Note:** While the dataset is being downloaded, feel free to look ahead at the upcoming code cells to get a sense of what we'll be doing next.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# ### Observations on Preprocessing
#
# - **Case and Punctuation:** Notice that none of the words in our dataset are capitalized, and there is no punctuation. This is likely due to preprocessing steps taken before we acquired the dataset, which ensures uniformity in the text.
# - **Preprocessing Considerations:** Preprocessing is a crucial part of NLP tasks, and its specifics depend on the data and the intended use. For instance, while we're working with unigrams (single words), other tasks might benefit from encoding n-grams (combinations of words) to capture context better.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %% [markdown]
# Now that we have our text data, the next step is to build a dictionary. This dictionary will map each unique word in our dataset to a unique integer code.
#
# Additionally, we'll keep track of the frequency of each word, which will help us prioritize the most common words.

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# ### Understanding the Key Variables
#
# - **`data`:** A list of integer codes representing the words in the original text. Each word is replaced by its corresponding code from the `dictionary`.
# - **`count`:** A list of tuples where each tuple contains a word and its frequency count in the dataset.
# - **`dictionary`:** A dictionary mapping each word to its unique integer code.
# - **`reverse_dictionary`:** A reverse mapping that converts integer codes back to their corresponding words.

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:')
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Least common words:')
print(*count[-5:], sep="\n")
# Out:
# Least common words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ### Step 3: Generate a Training Batch for the Skip-Gram Model
#
# In this step, we'll create a function to generate training batches for our skip-gram model. The skip-gram model is a variant of Word2Vec that predicts the context words given a target word. This function will help us prepare the data in the correct format for training the model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8,
                               num_skips=2,
                               skip_window=1)

# %%
# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----
#
# The Skip-Gram model is a type of neural network model used in Natural Language Processing (NLP) to learn distributed representations of words, commonly known as word embeddings.
#
# Word embeddings are dense vector representations of words that capture semantic relationships between them, meaning that words with similar meanings are mapped to similar points in the vector space.
#
# ### How the Skip-Gram Model Works
# The goal of the Skip-Gram model is to predict the context words given a target word. Here's how it works:
#
# Input: The model takes a single word (the target word) from the text as input.
#
# Output: The model is trained to predict words that are likely to appear in the context of the target word within a specified window of words before and after the target word. This context window is typically referred to as the "skip window."
#
# For example, if the sentence is "The cat sat on the mat," and the target word is "sat," the model might be asked to predict the words "The," "cat," "on," and "the," which appear around "sat."

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
import tensorflow.compat.v1 as v1

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = v1.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            v1.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = v1.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = v1.global_variables_initializer()

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  323.203857421875
# Nearest to 'this': compactly, staple, mak, regards,
# Nearest to 'th': unacceptable, whitey, vigor, crist,
# Nearest to 'known': hermeneutic, agglutinative, republika, sociology,
# Nearest to 'of': popper, lg, cameron, vulgaris,
# Nearest to 'or': indigenous, yew, folds, paullus,
# Nearest to 'that': trust, ztt, nanaimo, vows,
# Nearest to 'will': meta, axum, argentinean, encyclopedists,
# Nearest to 'three': departing, foetus, audi, miyazaki,
# Nearest to 'was': miriam, dismiss, assembly, starling,
# Nearest to 'no': roaring, sepia, sideline, empedocles,
# Nearest to 'been': sergei, chronometer, hadn, affecting,
# Nearest to 'd': misunderstood, frodo, cough, usr,
# Nearest to 'american': zoomed, swell, parmenides, tornadoes,
# Nearest to 'only': raging, ero, maradns, popping,
# Nearest to 'has': prose, slips, vivaldi, clinging,
# Nearest to 'its': inklings, dyed, noumenon, ayling,
#
# Average loss at step  2000 :  113.85572039890289
# Nearest to 'this': ideas, logic, vs, mortal,
# Nearest to 'th': operating, anarchists, europe, those,
# Nearest to 'known': autistic, late, sociology, traditional,
# Nearest to 'of': and, g, the, in,
# Nearest to 'or': key, eight, indigenous, frame,
# Nearest to 'that': trust, making, growth, zero,
# Nearest to 'will': married, meta, vs, european,
# Nearest to 'three': article, why, vs, inhabitants,
# Nearest to 'was': vs, branch, book, no,
# Nearest to 'no': give, unity, field, way,
# Nearest to 'been': pope, dominant, crown, lower,
# Nearest to 'd': sense, not, microcosm, julian,
# Nearest to 'american': lick, make, vs, md,
# Nearest to 'only': if, per, canadian, scott,
# Nearest to 'has': family, dr, translator, stone,
# Nearest to 'its': are, nine, texas, sympathetic,
#
# Average loss at step  4000 :  52.99324070715904
# Nearest to 'this': logic, estimated, ideas, doing,
# Nearest to 'th': tissue, operating, fao, europe,
# Nearest to 'known': autistic, late, tissue, sociology,
# Nearest to 'of': in, and, the, UNK,
# Nearest to 'or': saul, nationality, key, plot,
# Nearest to 'that': trust, growth, making, zero,
# Nearest to 'will': married, destroyed, vs, meta,
# Nearest to 'three': why, inhabitants, nine, article,
# Nearest to 'was': by, branch, vs, in,
# Nearest to 'no': gland, give, unity, field,
# Nearest to 'been': dominant, pope, crown, lower,
# Nearest to 'd': sense, ada, misunderstood, not,
# Nearest to 'american': afer, revolutionary, lick, make,
# Nearest to 'only': canadian, if, vila, per,
# Nearest to 'has': var, siberia, dr, farther,
# Nearest to 'its': basins, municipal, noumenon, texas,
#
# Average loss at step  6000 :  33.18421886098385
# Nearest to 'this': the, estimated, logic, neon,
# Nearest to 'th': tissue, dddddd, operating, fao,
# Nearest to 'known': rudolph, autistic, late, tissue,
# Nearest to 'of': in, and, touring, UNK,
# Nearest to 'or': and, trench, saul, taking,
# Nearest to 'that': trust, pill, programming, tips,
# Nearest to 'will': aphex, destroyed, married, sheet,
# Nearest to 'three': audi, why, nine, inhabitants,
# Nearest to 'was': is, by, branch, in,
# Nearest to 'no': unity, gland, give, sideline,
# Nearest to 'been': sergei, hadn, dominant, pope,
# Nearest to 'd': misunderstood, rotate, sense, ada,
# Nearest to 'american': revolutionary, afer, pennsylvania, hindu,
# Nearest to 'only': canadian, pregnancies, if, vila,
# Nearest to 'has': siberia, var, dr, translator,
# Nearest to 'its': basins, noumenon, municipal, sympathetic,
#
# Average loss at step  8000 :  23.730933616518975
# Nearest to 'this': the, estimated, a, doing,
# Nearest to 'th': tissue, operating, five, dddddd,
# Nearest to 'known': rudolph, autistic, late, traditional,
# Nearest to 'of': in, and, from, var,
# Nearest to 'or': and, UNK, trench, reduction,
# Nearest to 'that': trust, programming, making, fayyum,
# Nearest to 'will': meta, aphex, UNK, mctaggart,
# Nearest to 'three': nine, zero, why, two,
# Nearest to 'was': is, by, branch, in,
# Nearest to 'no': unity, gland, give, deductive,
# Nearest to 'been': sergei, hadn, pope, senior,
# Nearest to 'd': altenberg, misunderstood, rotate, sense,
# Nearest to 'american': revolutionary, pennsylvania, afer, hindu,
# Nearest to 'only': canadian, UNK, localities, archie,
# Nearest to 'has': waterloo, siberia, var, was,
# Nearest to 'its': basins, noumenon, municipal, sympathetic,
#
# Average loss at step  10000 :  17.53481297302246
# Nearest to 'this': the, estimated, a, its,
# Nearest to 'th': tissue, operating, five, dddddd,
# Nearest to 'known': rudolph, late, autistic, alpine,
# Nearest to 'of': in, and, for, from,
# Nearest to 'or': and, of, UNK, trench,
# Nearest to 'that': trust, programming, psalms, month,
# Nearest to 'will': mathbf, meta, aphex, mctaggart,
# Nearest to 'three': nine, zero, two, one,
# Nearest to 'was': is, by, had, branch,
# Nearest to 'no': unity, deductive, earned, give,
# Nearest to 'been': sergei, hadn, pope, senior,
# Nearest to 'd': altenberg, misunderstood, rotate, weekend,
# Nearest to 'american': revolutionary, abwehr, reid, pennsylvania,
# Nearest to 'only': localities, canadian, per, vila,
# Nearest to 'has': waterloo, siberia, was, var,
# Nearest to 'its': basins, satisfies, noumenon, municipal,
#
# Average loss at step  12000 :  14.028808817625047
# Nearest to 'this': the, estimated, a, its,
# Nearest to 'th': tissue, operating, five, dddddd,
# Nearest to 'known': rudolph, autistic, alpine, mate,
# Nearest to 'of': and, in, for, from,
# Nearest to 'or': and, UNK, of, trench,
# Nearest to 'that': trust, peptide, programming, month,
# Nearest to 'will': mathbf, aphex, meta, mctaggart,
# Nearest to 'three': nine, two, one, zero,
# Nearest to 'was': is, by, had, are,
# Nearest to 'no': unity, deductive, earned, give,
# Nearest to 'been': sergei, hadn, senior, pope,
# Nearest to 'd': syllabic, altenberg, rotate, misunderstood,
# Nearest to 'american': revolutionary, swell, abwehr, pennsylvania,
# Nearest to 'only': canadian, localities, kilda, piano,
# Nearest to 'has': waterloo, was, is, siberia,
# Nearest to 'its': the, satisfies, this, municipal,
#
# Average loss at step  14000 :  11.68717718911171
# Nearest to 'this': the, a, estimated, its,
# Nearest to 'th': tissue, five, operating, dddddd,
# Nearest to 'known': rudolph, mate, alphorn, autistic,
# Nearest to 'of': and, in, circ, for,
# Nearest to 'or': and, pelvic, trench, agouti,
# Nearest to 'that': trust, and, dasyprocta, programming,
# Nearest to 'will': mathbf, aphex, meta, agouti,
# Nearest to 'three': two, nine, one, circ,
# Nearest to 'was': is, by, had, are,
# Nearest to 'no': unity, deductive, earned, give,
# Nearest to 'been': operatorname, sergei, by, senior,
# Nearest to 'd': and, syllabic, rotate, altenberg,
# Nearest to 'american': revolutionary, swell, hindu, pennsylvania,
# Nearest to 'only': localities, canadian, kilda, vila,
# Nearest to 'has': vivaldi, waterloo, was, circ,
# Nearest to 'its': the, satisfies, this, basins,
#
# Average loss at step  16000 :  9.93490021622181
# Nearest to 'this': the, a, its, estimated,
# Nearest to 'th': five, tissue, eight, operating,
# Nearest to 'known': rudolph, mate, alphorn, antibiotic,
# Nearest to 'of': and, in, circ, from,
# Nearest to 'or': and, pelvic, eight, UNK,
# Nearest to 'that': trust, which, and, programming,
# Nearest to 'will': mathbf, aphex, meta, agouti,
# Nearest to 'three': nine, two, zero, seven,
# Nearest to 'was': is, by, had, are,
# Nearest to 'no': unity, deductive, earned, a,
# Nearest to 'been': operatorname, sergei, by, senior,
# Nearest to 'd': b, and, rotate, syllabic,
# Nearest to 'american': and, agouti, revolutionary, pennsylvania,
# Nearest to 'only': localities, canadian, piano, kilda,
# Nearest to 'has': vivaldi, waterloo, is, was,
# Nearest to 'its': the, this, satisfies, basins,
#
# Average loss at step  18000 :  8.412205242156983
# Nearest to 'this': the, a, its, estimated,
# Nearest to 'th': eight, five, zero, tissue,
# Nearest to 'known': rudolph, mate, incompressible, alphorn,
# Nearest to 'of': in, and, circ, from,
# Nearest to 'or': and, eight, pelvic, agouti,
# Nearest to 'that': which, trust, dasyprocta, programming,
# Nearest to 'will': mathbf, aphex, meta, agouti,
# Nearest to 'three': nine, two, seven, zero,
# Nearest to 'was': is, by, had, are,
# Nearest to 'no': unity, deductive, a, earned,
# Nearest to 'been': operatorname, sergei, by, senior,
# Nearest to 'd': b, and, one, rotate,
# Nearest to 'american': and, one, pennsylvania, revolutionary,
# Nearest to 'only': localities, kilda, canadian, schopenhauer,
# Nearest to 'has': was, waterloo, vivaldi, is,
# Nearest to 'its': the, this, satisfies, basins,
#
# Average loss at step  20000 :  8.079592672824859
# Nearest to 'this': the, a, its, estimated,
# Nearest to 'th': five, eight, zero, nine,
# Nearest to 'known': rudolph, courtly, mate, incompressible,
# Nearest to 'of': and, in, for, circ,
# Nearest to 'or': and, UNK, pelvic, trench,
# Nearest to 'that': which, and, dasyprocta, dtp,
# Nearest to 'will': mathbf, aphex, meta, overlap,
# Nearest to 'three': two, nine, seven, zero,
# Nearest to 'was': is, by, had, are,
# Nearest to 'no': unity, a, deductive, earned,
# Nearest to 'been': by, operatorname, sergei, was,
# Nearest to 'd': b, and, rotate, syllabic,
# Nearest to 'american': antwerp, and, agouti, pennsylvania,
# Nearest to 'only': localities, sandstone, canadian, swinburne,
# Nearest to 'has': was, is, waterloo, had,
# Nearest to 'its': the, this, satisfies, basins,
#
# Average loss at step  22000 :  6.948927022337913
# Nearest to 'this': the, a, its, it,
# Nearest to 'th': five, zero, eight, three,
# Nearest to 'known': rudolph, mate, incompressible, courtly,
# Nearest to 'of': in, and, for, circ,
# Nearest to 'or': and, UNK, eight, pelvic,
# Nearest to 'that': which, dasyprocta, operatorname, trust,
# Nearest to 'will': mathbf, aphex, meta, overlap,
# Nearest to 'three': two, seven, six, eight,
# Nearest to 'was': is, by, had, are,
# Nearest to 'no': unity, a, deductive, earned,
# Nearest to 'been': operatorname, by, sergei, was,
# Nearest to 'd': b, and, rotate, syllabic,
# Nearest to 'american': antwerp, agouti, and, revolutionary,
# Nearest to 'only': localities, sandstone, swinburne, schopenhauer,
# Nearest to 'has': was, had, is, waterloo,
# Nearest to 'its': the, this, satisfies, their,
#
# Average loss at step  24000 :  6.846950508117676
# Nearest to 'this': the, it, a, its,
# Nearest to 'th': eight, five, zero, nine,
# Nearest to 'known': rudolph, incompressible, mate, courtly,
# Nearest to 'of': in, and, for, circ,
# Nearest to 'or': and, than, trench, dasyprocta,
# Nearest to 'that': which, operatorname, month, dasyprocta,
# Nearest to 'will': mathbf, aphex, can, overlap,
# Nearest to 'three': two, seven, six, five,
# Nearest to 'was': is, by, had, are,
# Nearest to 'no': unity, a, deductive, earned,
# Nearest to 'been': operatorname, by, was, sergei,
# Nearest to 'd': b, rotate, and, usr,
# Nearest to 'american': antwerp, and, agouti, pennsylvania,
# Nearest to 'only': localities, sandstone, schopenhauer, swinburne,
# Nearest to 'has': was, had, is, waterloo,
# Nearest to 'its': the, this, their, satisfies,
#
# Average loss at step  26000 :  6.654204586029053
# Nearest to 'this': the, it, its, a,
# Nearest to 'th': eight, five, zero, seven,
# Nearest to 'known': rudolph, incompressible, mate, courtly,
# Nearest to 'of': in, and, circ, for,
# Nearest to 'or': and, dasyprocta, six, trench,
# Nearest to 'that': which, month, operatorname, dasyprocta,
# Nearest to 'will': can, mathbf, aphex, would,
# Nearest to 'three': six, two, five, seven,
# Nearest to 'was': is, by, had, has,
# Nearest to 'no': unity, deductive, a, earned,
# Nearest to 'been': by, operatorname, was, sergei,
# Nearest to 'd': b, rotate, usr, and,
# Nearest to 'american': antwerp, and, agouti, pennsylvania,
# Nearest to 'only': localities, sandstone, schopenhauer, swinburne,
# Nearest to 'has': was, had, is, waterloo,
# Nearest to 'its': the, this, their, satisfies,
#
# Average loss at step  28000 :  6.385546049118042
# Nearest to 'this': the, it, morita, its,
# Nearest to 'th': eight, five, zero, seven,
# Nearest to 'known': rudolph, incompressible, mate, courtly,
# Nearest to 'of': in, for, and, circ,
# Nearest to 'or': and, than, six, dasyprocta,
# Nearest to 'that': which, abakan, this, operatorname,
# Nearest to 'will': can, would, aphex, mathbf,
# Nearest to 'three': six, eight, five, seven,
# Nearest to 'was': is, had, by, were,
# Nearest to 'no': unity, a, deductive, trinomial,
# Nearest to 'been': by, operatorname, was, sergei,
# Nearest to 'd': b, and, rotate, usr,
# Nearest to 'american': and, antwerp, agouti, socialite,
# Nearest to 'only': localities, sandstone, schopenhauer, swinburne,
# Nearest to 'has': was, had, is, waterloo,
# Nearest to 'its': the, their, this, satisfies,
#
# Average loss at step  30000 :  5.891897110581398
# Nearest to 'this': the, it, morita, its,
# Nearest to 'th': eight, zero, three, arin,
# Nearest to 'known': arin, rudolph, incompressible, mate,
# Nearest to 'of': in, and, for, circ,
# Nearest to 'or': and, than, dasyprocta, six,
# Nearest to 'that': which, abakan, operatorname, it,
# Nearest to 'will': can, would, to, mathbf,
# Nearest to 'three': five, two, six, four,
# Nearest to 'was': is, had, by, were,
# Nearest to 'no': unity, a, deductive, trinomial,
# Nearest to 'been': by, was, operatorname, sergei,
# Nearest to 'd': b, rotate, usr, and,
# Nearest to 'american': and, antwerp, agouti, pennsylvania,
# Nearest to 'only': localities, sandstone, schopenhauer, mauritius,
# Nearest to 'has': had, was, is, waterloo,
# Nearest to 'its': the, their, this, basins,
#
# Average loss at step  32000 :  5.98311655730009
# Nearest to 'this': the, it, its, morita,
# Nearest to 'th': eight, zero, seven, six,
# Nearest to 'known': arin, rudolph, incompressible, mate,
# Nearest to 'of': and, in, for, circ,
# Nearest to 'or': and, dasyprocta, than, trench,
# Nearest to 'that': which, abakan, this, dasyprocta,
# Nearest to 'will': can, would, to, mathbf,
# Nearest to 'three': six, five, seven, four,
# Nearest to 'was': is, had, by, were,
# Nearest to 'no': unity, a, deductive, trinomial,
# Nearest to 'been': by, was, operatorname, sergei,
# Nearest to 'd': b, usr, rotate, analgesics,
# Nearest to 'american': antwerp, and, agouti, pennsylvania,
# Nearest to 'only': localities, sandstone, schopenhauer, mauritius,
# Nearest to 'has': had, was, is, waterloo,
# Nearest to 'its': the, their, this, basins,
#
# Average loss at step  34000 :  5.669634948730469
# Nearest to 'this': the, it, which, its,
# Nearest to 'th': eight, seven, three, six,
# Nearest to 'known': arin, rudolph, incompressible, mate,
# Nearest to 'of': in, and, for, circ,
# Nearest to 'or': and, than, dasyprocta, trench,
# Nearest to 'that': which, abakan, this, but,
# Nearest to 'will': can, would, to, aphex,
# Nearest to 'three': six, five, four, seven,
# Nearest to 'was': is, had, by, were,
# Nearest to 'no': a, unity, deductive, trinomial,
# Nearest to 'been': by, was, operatorname, sergei,
# Nearest to 'd': b, rotate, usr, zero,
# Nearest to 'american': and, antwerp, agouti, arexx,
# Nearest to 'only': localities, sandstone, mauritius, cli,
# Nearest to 'has': had, was, is, waterloo,
# Nearest to 'its': the, their, this, his,
#
# Average loss at step  36000 :  5.730352427959442
# Nearest to 'this': the, it, which, its,
# Nearest to 'th': eight, seven, six, zero,
# Nearest to 'known': rudolph, arin, incompressible, mate,
# Nearest to 'of': circ, in, nine, for,
# Nearest to 'or': and, than, dasyprocta, trench,
# Nearest to 'that': which, abakan, this, but,
# Nearest to 'will': can, would, to, where,
# Nearest to 'three': six, five, seven, four,
# Nearest to 'was': is, had, by, were,
# Nearest to 'no': a, unity, deductive, trinomial,
# Nearest to 'been': by, was, operatorname, were,
# Nearest to 'd': b, usr, rotate, and,
# Nearest to 'american': antwerp, and, agouti, arexx,
# Nearest to 'only': localities, sandstone, editorial, cli,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': the, their, this, his,
#
# Average loss at step  38000 :  5.540951304674149
# Nearest to 'this': it, which, the, its,
# Nearest to 'th': eight, seven, six, zero,
# Nearest to 'known': rudolph, arin, incompressible, mate,
# Nearest to 'of': and, in, for, from,
# Nearest to 'or': and, than, dasyprocta, trench,
# Nearest to 'that': which, but, abakan, this,
# Nearest to 'will': can, would, cannot, where,
# Nearest to 'three': six, five, four, seven,
# Nearest to 'was': is, had, by, has,
# Nearest to 'no': a, unity, deductive, trinomial,
# Nearest to 'been': was, by, operatorname, were,
# Nearest to 'd': b, usr, rotate, lions,
# Nearest to 'american': and, antwerp, agouti, pennsylvania,
# Nearest to 'only': localities, mauritius, sandstone, editorial,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': the, their, this, his,
#
# Average loss at step  40000 :  5.263662605047226
# Nearest to 'this': it, which, the, its,
# Nearest to 'th': eight, seven, zero, six,
# Nearest to 'known': arin, rudolph, used, incompressible,
# Nearest to 'of': in, circ, for, and,
# Nearest to 'or': and, dasyprocta, than, zero,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, cannot, where,
# Nearest to 'three': four, five, six, eight,
# Nearest to 'was': is, had, by, has,
# Nearest to 'no': a, unity, deductive, trinomial,
# Nearest to 'been': was, by, operatorname, be,
# Nearest to 'd': b, usr, rotate, zero,
# Nearest to 'american': antwerp, and, agouti, arexx,
# Nearest to 'only': localities, mauritius, sandstone, popping,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': the, their, this, his,
#
# Average loss at step  42000 :  5.36744261431694
# Nearest to 'this': the, it, which, its,
# Nearest to 'th': seven, eight, six, zero,
# Nearest to 'known': rudolph, arin, used, incompressible,
# Nearest to 'of': in, circ, from, and,
# Nearest to 'or': and, than, dasyprocta, agouti,
# Nearest to 'that': which, this, abakan, but,
# Nearest to 'will': can, would, cannot, could,
# Nearest to 'three': five, four, six, two,
# Nearest to 'was': is, had, by, were,
# Nearest to 'no': unity, a, deductive, trinomial,
# Nearest to 'been': was, by, operatorname, be,
# Nearest to 'd': b, UNK, outfielders, usr,
# Nearest to 'american': and, antwerp, agouti, pennsylvania,
# Nearest to 'only': localities, mauritius, sandstone, popping,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, this,
#
# Average loss at step  44000 :  5.237237799882889
# Nearest to 'this': it, the, which, its,
# Nearest to 'th': five, eight, seven, six,
# Nearest to 'known': rudolph, incompressible, arin, used,
# Nearest to 'of': and, circ, in, from,
# Nearest to 'or': and, than, dasyprocta, four,
# Nearest to 'that': which, this, abakan, but,
# Nearest to 'will': can, would, cannot, could,
# Nearest to 'three': four, five, six, eight,
# Nearest to 'was': is, had, were, by,
# Nearest to 'no': unity, a, deductive, trinomial,
# Nearest to 'been': was, by, operatorname, be,
# Nearest to 'd': b, outfielders, usr, rotate,
# Nearest to 'american': antwerp, and, agouti, pennsylvania,
# Nearest to 'only': localities, mauritius, sandstone, four,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, this,
#
# Average loss at step  46000 :  5.217214047551155
# Nearest to 'this': it, which, the, that,
# Nearest to 'th': six, five, eight, three,
# Nearest to 'known': used, incompressible, rudolph, arin,
# Nearest to 'of': in, circ, for, and,
# Nearest to 'or': and, than, dasyprocta, six,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, cannot, could,
# Nearest to 'three': four, five, six, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, trinomial, deductive,
# Nearest to 'been': was, by, operatorname, be,
# Nearest to 'd': b, UNK, outfielders, rotate,
# Nearest to 'american': antwerp, agouti, french, english,
# Nearest to 'only': localities, mauritius, four, six,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, this,
#
# Average loss at step  48000 :  5.222806242227555
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': three, seven, six, eight,
# Nearest to 'known': used, incompressible, rudolph, arin,
# Nearest to 'of': in, circ, for, nine,
# Nearest to 'or': and, than, dasyprocta, kapoor,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, to, cannot,
# Nearest to 'three': four, six, five, eight,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, trinomial, deductive,
# Nearest to 'been': was, by, be, operatorname,
# Nearest to 'd': b, UNK, outfielders, usr,
# Nearest to 'american': antwerp, agouti, and, french,
# Nearest to 'only': mauritius, localities, popping, no,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  50000 :  5.02280769777298
# Nearest to 'this': it, which, the, that,
# Nearest to 'th': three, seven, six, eight,
# Nearest to 'known': incompressible, used, rudolph, arin,
# Nearest to 'of': in, for, circ, nine,
# Nearest to 'or': and, six, than, dasyprocta,
# Nearest to 'that': which, this, abakan, but,
# Nearest to 'will': can, would, cannot, could,
# Nearest to 'three': four, six, five, eight,
# Nearest to 'was': is, were, had, by,
# Nearest to 'no': a, unity, deductive, roaring,
# Nearest to 'been': was, by, be, operatorname,
# Nearest to 'd': b, outfielders, six, usr,
# Nearest to 'american': antwerp, agouti, kapoor, french,
# Nearest to 'only': mauritius, four, kapoor, popping,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  52000 :  5.015934445142746
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': three, six, eight, seven,
# Nearest to 'known': used, incompressible, arin, rudolph,
# Nearest to 'of': in, circ, and, for,
# Nearest to 'or': and, than, dasyprocta, agouti,
# Nearest to 'that': which, this, abakan, but,
# Nearest to 'will': can, would, could, cannot,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, were, had, has,
# Nearest to 'no': a, unity, trinomial, deductive,
# Nearest to 'been': was, by, be, operatorname,
# Nearest to 'd': b, outfielders, usr, kennel,
# Nearest to 'american': antwerp, and, french, english,
# Nearest to 'only': mauritius, ursus, sandstone, localities,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  54000 :  5.182022257208824
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': three, six, seven, eight,
# Nearest to 'known': used, incompressible, arin, rudolph,
# Nearest to 'of': circ, in, for, and,
# Nearest to 'or': and, than, six, dasyprocta,
# Nearest to 'that': which, but, this, abakan,
# Nearest to 'will': can, would, cannot, could,
# Nearest to 'three': six, five, two, four,
# Nearest to 'was': is, were, had, has,
# Nearest to 'no': a, unity, trinomial, deductive,
# Nearest to 'been': was, be, by, operatorname,
# Nearest to 'd': b, six, outfielders, usr,
# Nearest to 'american': antwerp, and, french, english,
# Nearest to 'only': wct, ursus, mauritius, four,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  56000 :  5.042408484220505
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': six, seven, three, eight,
# Nearest to 'known': used, incompressible, arin, rudolph,
# Nearest to 'of': circ, in, and, for,
# Nearest to 'or': and, than, six, kapoor,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, could, cannot,
# Nearest to 'three': six, four, five, two,
# Nearest to 'was': is, were, had, has,
# Nearest to 'no': a, unity, trinomial, deductive,
# Nearest to 'been': be, was, by, operatorname,
# Nearest to 'd': b, outfielders, usr, kennel,
# Nearest to 'american': and, antwerp, french, english,
# Nearest to 'only': wct, ursus, mauritius, popping,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  58000 :  5.070908358097077
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': six, seven, eight, five,
# Nearest to 'known': used, incompressible, mate, arin,
# Nearest to 'of': in, circ, for, nine,
# Nearest to 'or': and, than, dasyprocta, wct,
# Nearest to 'that': which, this, abakan, but,
# Nearest to 'will': can, would, could, cannot,
# Nearest to 'three': six, four, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, only, it,
# Nearest to 'been': be, was, by, operatorname,
# Nearest to 'd': b, outfielders, usr, kennel,
# Nearest to 'american': and, antwerp, french, english,
# Nearest to 'only': wct, four, ursus, mauritius,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  60000 :  4.952587029576302
# Nearest to 'this': which, it, that, the,
# Nearest to 'th': eight, six, seven, five,
# Nearest to 'known': used, incompressible, mate, arin,
# Nearest to 'of': in, and, circ, nine,
# Nearest to 'or': and, than, wct, dasyprocta,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, could, cannot,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, moonlight, deductive,
# Nearest to 'been': was, be, by, operatorname,
# Nearest to 'd': b, outfielders, usr, kennel,
# Nearest to 'american': and, antwerp, french, english,
# Nearest to 'only': wct, ursus, mauritius, four,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  62000 :  5.039065356373787
# Nearest to 'this': which, it, that, the,
# Nearest to 'th': six, eight, five, seven,
# Nearest to 'known': used, leontopithecus, incompressible, mate,
# Nearest to 'of': and, circ, in, dasyprocta,
# Nearest to 'or': and, microcebus, eight, than,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, could, cannot,
# Nearest to 'three': six, four, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, it, trinomial,
# Nearest to 'been': be, was, by, operatorname,
# Nearest to 'd': b, outfielders, usr, e,
# Nearest to 'american': antwerp, french, and, english,
# Nearest to 'only': wct, ursus, mauritius, four,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, the, his, callithrix,
#
# Average loss at step  64000 :  4.83589558917284
# Nearest to 'this': which, it, that, the,
# Nearest to 'th': six, five, seven, eight,
# Nearest to 'known': used, leontopithecus, incompressible, well,
# Nearest to 'of': circ, in, and, for,
# Nearest to 'or': and, microcebus, than, wct,
# Nearest to 'that': which, this, abakan, but,
# Nearest to 'will': can, would, could, cannot,
# Nearest to 'three': five, four, six, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, there, trinomial,
# Nearest to 'been': be, was, operatorname, by,
# Nearest to 'd': b, outfielders, usr, e,
# Nearest to 'american': and, antwerp, french, english,
# Nearest to 'only': wct, ursus, mauritius, four,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  66000 :  4.590905691385269
# Nearest to 'this': which, it, that, the,
# Nearest to 'th': six, five, eight, three,
# Nearest to 'known': used, leontopithecus, incompressible, such,
# Nearest to 'of': circ, for, in, agouti,
# Nearest to 'or': and, microcebus, than, wct,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, could, cannot,
# Nearest to 'three': four, five, six, seven,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, any, trinomial,
# Nearest to 'been': be, was, operatorname, were,
# Nearest to 'd': b, UNK, outfielders, usr,
# Nearest to 'american': and, antwerp, french, pennsylvania,
# Nearest to 'only': wct, four, ursus, mauritius,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  68000 :  4.98663571858406
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': six, five, eight, seven,
# Nearest to 'known': used, leontopithecus, such, incompressible,
# Nearest to 'of': circ, in, dasyprocta, mitral,
# Nearest to 'or': and, microcebus, wct, dasyprocta,
# Nearest to 'that': which, this, abakan, wct,
# Nearest to 'will': can, would, could, cannot,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, any, trinomial,
# Nearest to 'been': be, was, by, operatorname,
# Nearest to 'd': b, UNK, outfielders, usr,
# Nearest to 'american': antwerp, french, and, pennsylvania,
# Nearest to 'only': wct, ursus, mauritius, mitral,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  70000 :  4.921015395760536
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': six, eight, three, five,
# Nearest to 'known': used, leontopithecus, incompressible, such,
# Nearest to 'of': circ, and, in, dasyprocta,
# Nearest to 'or': and, microcebus, agouti, dasyprocta,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, any, there,
# Nearest to 'been': be, was, operatorname, by,
# Nearest to 'd': b, UNK, outfielders, usr,
# Nearest to 'american': french, and, antwerp, english,
# Nearest to 'only': wct, ursus, mitral, kapoor,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  72000 :  4.734678222060204
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': six, five, seven, eight,
# Nearest to 'known': used, such, leontopithecus, well,
# Nearest to 'of': circ, nine, in, for,
# Nearest to 'or': and, microcebus, agouti, dasyprocta,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, any, there,
# Nearest to 'been': be, was, were, operatorname,
# Nearest to 'd': b, UNK, outfielders, usr,
# Nearest to 'american': and, antwerp, french, english,
# Nearest to 'only': wct, four, ursus, mitral,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  74000 :  4.797960674285888
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': six, five, seven, eight,
# Nearest to 'known': used, such, leontopithecus, incompressible,
# Nearest to 'of': circ, dasyprocta, for, agouti,
# Nearest to 'or': and, microcebus, four, kapoor,
# Nearest to 'that': which, this, but, abakan,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, any, there,
# Nearest to 'been': be, was, were, by,
# Nearest to 'd': b, UNK, n, outfielders,
# Nearest to 'american': french, antwerp, and, english,
# Nearest to 'only': wct, ursus, mitral, four,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  76000 :  4.738473957657814
# Nearest to 'this': which, it, that, the,
# Nearest to 'th': seven, six, three, five,
# Nearest to 'known': used, leontopithecus, such, incompressible,
# Nearest to 'of': circ, in, dasyprocta, for,
# Nearest to 'or': and, microcebus, dasyprocta, kapoor,
# Nearest to 'that': which, this, but, cannibal,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, there, any,
# Nearest to 'been': be, was, were, by,
# Nearest to 'd': b, UNK, n, outfielders,
# Nearest to 'american': french, and, antwerp, english,
# Nearest to 'only': wct, ursus, mitral, gaddis,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  78000 :  4.793880347490311
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': seven, six, three, five,
# Nearest to 'known': used, such, leontopithecus, incompressible,
# Nearest to 'of': circ, in, dasyprocta, mitral,
# Nearest to 'or': and, microcebus, dasyprocta, than,
# Nearest to 'that': which, this, but, cannibal,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, there, any,
# Nearest to 'been': be, was, were, by,
# Nearest to 'd': b, n, outfielders, usr,
# Nearest to 'american': french, antwerp, english, and,
# Nearest to 'only': wct, ursus, mitral, gaddis,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  80000 :  4.809101223409176
# Nearest to 'this': which, it, that, the,
# Nearest to 'th': six, seven, five, eight,
# Nearest to 'known': used, such, leontopithecus, incompressible,
# Nearest to 'of': in, circ, iit, dasyprocta,
# Nearest to 'or': and, microcebus, than, dasyprocta,
# Nearest to 'that': which, this, iit, abakan,
# Nearest to 'will': would, can, could, may,
# Nearest to 'three': four, five, six, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': unity, a, there, any,
# Nearest to 'been': be, was, by, were,
# Nearest to 'd': b, UNK, n, lions,
# Nearest to 'american': french, antwerp, english, pennsylvania,
# Nearest to 'only': wct, ursus, mitral, gaddis,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  82000 :  4.7781104960441585
# Nearest to 'this': which, it, the, iit,
# Nearest to 'th': six, eight, seven, five,
# Nearest to 'known': used, such, leontopithecus, incompressible,
# Nearest to 'of': circ, nine, iit, mitral,
# Nearest to 'or': and, microcebus, dasyprocta, wct,
# Nearest to 'that': which, iit, this, abakan,
# Nearest to 'will': would, can, could, may,
# Nearest to 'three': four, five, six, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': unity, there, any, futurists,
# Nearest to 'been': be, was, were, become,
# Nearest to 'd': b, outfielders, n, e,
# Nearest to 'american': french, antwerp, english, iit,
# Nearest to 'only': wct, ursus, mitral, gaddis,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  84000 :  4.746861790060997
# Nearest to 'this': which, it, the, iit,
# Nearest to 'th': eight, six, seven, five,
# Nearest to 'known': used, such, leontopithecus, incompressible,
# Nearest to 'of': circ, iit, in, dasyprocta,
# Nearest to 'or': and, microcebus, than, dasyprocta,
# Nearest to 'that': which, iit, this, however,
# Nearest to 'will': would, can, could, may,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, any, there,
# Nearest to 'been': be, was, become, were,
# Nearest to 'd': b, outfielders, n, lions,
# Nearest to 'american': french, english, antwerp, pennsylvania,
# Nearest to 'only': wct, ursus, mitral, gaddis,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  86000 :  4.7612179098129275
# Nearest to 'this': which, it, the, iit,
# Nearest to 'th': six, seven, eight, five,
# Nearest to 'known': used, such, leontopithecus, incompressible,
# Nearest to 'of': circ, iit, for, including,
# Nearest to 'or': and, microcebus, than, wct,
# Nearest to 'that': which, however, this, but,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, six, five, two,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': a, unity, any, futurists,
# Nearest to 'been': be, was, become, were,
# Nearest to 'd': b, outfielders, n, e,
# Nearest to 'american': french, english, antwerp, pennsylvania,
# Nearest to 'only': wct, ursus, mitral, gaddis,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  88000 :  4.745520929932594
# Nearest to 'this': which, it, the, iit,
# Nearest to 'th': six, seven, eight, five,
# Nearest to 'known': used, such, leontopithecus, incompressible,
# Nearest to 'of': circ, iit, christianum, including,
# Nearest to 'or': and, microcebus, dasyprocta, antwerp,
# Nearest to 'that': which, but, this, iit,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, five, two, six,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': any, a, unity, futurists,
# Nearest to 'been': be, was, were, become,
# Nearest to 'd': b, n, lions, outfielders,
# Nearest to 'american': french, english, antwerp, pennsylvania,
# Nearest to 'only': wct, ursus, popping, mitral,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  90000 :  4.746718019843102
# Nearest to 'this': which, it, the, iit,
# Nearest to 'th': six, seven, eight, five,
# Nearest to 'known': used, such, leontopithecus, well,
# Nearest to 'of': in, circ, iit, including,
# Nearest to 'or': and, microcebus, dasyprocta, than,
# Nearest to 'that': which, but, this, however,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, five, two, seven,
# Nearest to 'was': is, had, has, were,
# Nearest to 'no': any, a, unity, futurists,
# Nearest to 'been': be, was, were, become,
# Nearest to 'd': b, n, six, UNK,
# Nearest to 'american': french, english, antwerp, pennsylvania,
# Nearest to 'only': wct, ursus, mitral, popping,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  92000 :  4.659341784119606
# Nearest to 'this': which, it, the, that,
# Nearest to 'th': six, seven, eight, five,
# Nearest to 'known': used, such, well, leontopithecus,
# Nearest to 'of': circ, in, iit, nine,
# Nearest to 'or': and, microcebus, dasyprocta, than,
# Nearest to 'that': which, this, but, iit,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, five, two, seven,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': any, unity, a, futurists,
# Nearest to 'been': be, was, were, become,
# Nearest to 'd': b, n, six, e,
# Nearest to 'american': french, english, antwerp, pennsylvania,
# Nearest to 'only': wct, ursus, mitral, popping,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  94000 :  4.730622104525566
# Nearest to 'this': it, which, the, iit,
# Nearest to 'th': six, seven, eight, five,
# Nearest to 'known': used, such, well, leontopithecus,
# Nearest to 'of': circ, in, iit, for,
# Nearest to 'or': and, microcebus, dasyprocta, than,
# Nearest to 'that': which, iit, but, however,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, five, two, seven,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': any, unity, a, futurists,
# Nearest to 'been': be, was, were, become,
# Nearest to 'd': b, n, six, lions,
# Nearest to 'american': french, english, antwerp, pennsylvania,
# Nearest to 'only': wct, ursus, mitral, popping,
# Nearest to 'has': had, have, is, was,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  96000 :  4.688875564813614
# Nearest to 'this': it, which, the, iit,
# Nearest to 'th': six, seven, eight, five,
# Nearest to 'known': used, such, well, incompressible,
# Nearest to 'of': circ, iit, in, dasyprocta,
# Nearest to 'or': and, microcebus, than, dasyprocta,
# Nearest to 'that': which, but, however, iit,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': four, five, two, six,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': any, a, unity, futurists,
# Nearest to 'been': be, become, was, were,
# Nearest to 'd': b, n, six, outfielders,
# Nearest to 'american': french, english, antwerp, pennsylvania,
# Nearest to 'only': wct, ursus, mitral, popping,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, the, his, her,
#
# Average loss at step  98000 :  4.5921135629415515
# Nearest to 'this': it, which, the, iit,
# Nearest to 'th': six, seven, eight, five,
# Nearest to 'known': used, such, incompressible, leontopithecus,
# Nearest to 'of': circ, in, iit, including,
# Nearest to 'or': and, microcebus, than, dasyprocta,
# Nearest to 'that': which, but, however, this,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': five, four, two, seven,
# Nearest to 'was': is, had, were, has,
# Nearest to 'no': any, unity, futurists, another,
# Nearest to 'been': be, was, become, were,
# Nearest to 'd': b, n, outfielders, e,
# Nearest to 'american': french, english, pennsylvania, antwerp,
# Nearest to 'only': wct, ursus, mitral, popping,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, her,
#
# Average loss at step  100000 :  4.697400647878647
# Nearest to 'this': it, which, the, iit,
# Nearest to 'th': six, five, seven, eight,
# Nearest to 'known': used, such, incompressible, leontopithecus,
# Nearest to 'of': circ, in, iit, dasyprocta,
# Nearest to 'or': and, microcebus, than, dasyprocta,
# Nearest to 'that': which, but, this, iit,
# Nearest to 'will': can, would, could, may,
# Nearest to 'three': five, four, six, seven,
# Nearest to 'was': is, had, has, were,
# Nearest to 'no': any, unity, a, only,
# Nearest to 'been': be, was, become, were,
# Nearest to 'd': b, six, e, kapoor,
# Nearest to 'american': french, english, canadian, pennsylvania,
# Nearest to 'only': wct, ursus, mitral, popping,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, her,

# %% [markdown]
# <center><img src="https://github.com/Cutie-tee/lab-guided-tutorial-visualize-deep-learning-embeddings/blob/images/watiing.jpg?raw=1" width="700"/></center>

# %% [markdown]
# -----
# Step 6: Visualize the embeddings with t-SNE.
# ----

# %% [markdown]
# In this step, we use the t-SNE algorithm to reduce the dimensionality of the learned word embeddings for visualization.
#
# The top 500 words (based on frequency) are plotted in a 2D space, allowing us to visually inspect the relationships and groupings among words.
#
# This visualization is a powerful tool to understand how well the model has learned semantic relationships.

# %%
tsne = TSNE(perplexity=30,
            n_components=2,
            init='pca',
            n_iter=5_000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ------
#
# # Let's render and plot more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='../images/tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# # And voila!
#
# Now you have a visual understanding of embeddings.

# %% [markdown]
# Thank you for following this tutorial!
